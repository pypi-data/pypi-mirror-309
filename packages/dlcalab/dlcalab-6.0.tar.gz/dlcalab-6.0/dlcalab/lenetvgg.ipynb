# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import setuptools.distutils

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

def build_lenet():
    model = models.Sequential()
    model.add(layers.Conv2D(6, (5, 5), activation='relu', input_shape=(28, 28, 1)))
    model.add(layers.AveragePooling2D(pool_size=(2, 2)))
    model.add(layers.Conv2D(16, (5, 5), activation='relu'))
    model.add(layers.AveragePooling2D(pool_size=(2, 2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(120, activation='relu'))
    model.add(layers.Dense(84, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def build_vgg():
    model = models.Sequential()
    model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(28, 28, 1)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(2, 2))) 
    
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))  
    
    model.add(layers.Conv2D(256, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(2, 2))) 
    
    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))  
    model.add(layers.Dense(10, activation='softmax')) 
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model


lenet_model = build_lenet()
vgg_model = build_vgg()


print("Training LeNet Model...")
lenet_history = lenet_model.fit(x_train, y_train, epochs=10, batch_size=128, validation_data=(x_test, y_test), verbose=1)

print("Training VGG Model...")
vgg_history = vgg_model.fit(x_train, y_train, epochs=10, batch_size=128, validation_data=(x_test, y_test), verbose=1)

# Evaluate both models
lenet_test_loss, lenet_test_acc = lenet_model.evaluate(x_test, y_test, verbose=2)
vgg_test_loss, vgg_test_acc = vgg_model.evaluate(x_test, y_test, verbose=2)

print(f"\nLeNet Model Test accuracy: {lenet_test_acc:.4f}")
print(f"VGG Model Test accuracy: {vgg_test_acc:.4f}")
# Out:
# Training LeNet Model...
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7859 - loss: 0.7487 - val_accuracy: 0.9671 - val_loss: 0.1101
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9656 - loss: 0.1141 - val_accuracy: 0.9762 - val_loss: 0.0760
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9751 - loss: 0.0790 - val_accuracy: 0.9810 - val_loss: 0.0588
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9799 - loss: 0.0652 - val_accuracy: 0.9825 - val_loss: 0.0553
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9833 - loss: 0.0539 - val_accuracy: 0.9853 - val_loss: 0.0486
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9874 - loss: 0.0407 - val_accuracy: 0.9852 - val_loss: 0.0442
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9881 - loss: 0.0353 - val_accuracy: 0.9862 - val_loss: 0.0439
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9898 - loss: 0.0337 - val_accuracy: 0.9871 - val_loss: 0.0433
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9904 - loss: 0.0289 - val_accuracy: 0.9898 - val_loss: 0.0350
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9911 - loss: 0.0273 - val_accuracy: 0.9873 - val_loss: 0.0403
# Training VGG Model...
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 57s 117ms/step - accuracy: 0.8521 - loss: 0.4433 - val_accuracy: 0.9851 - val_loss: 0.0471
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 55s 117ms/step - accuracy: 0.9876 - loss: 0.0403 - val_accuracy: 0.9908 - val_loss: 0.0302
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 55s 117ms/step - accuracy: 0.9912 - loss: 0.0278 - val_accuracy: 0.9900 - val_loss: 0.0322
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 58s 124ms/step - accuracy: 0.9941 - loss: 0.0197 - val_accuracy: 0.9921 - val_loss: 0.0288
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 58s 123ms/step - accuracy: 0.9954 - loss: 0.0147 - val_accuracy: 0.9918 - val_loss: 0.0274
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 59s 126ms/step - accuracy: 0.9951 - loss: 0.0147 - val_accuracy: 0.9917 - val_loss: 0.0300
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 61s 129ms/step - accuracy: 0.9957 - loss: 0.0138 - val_accuracy: 0.9909 - val_loss: 0.0335
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 58s 123ms/step - accuracy: 0.9964 - loss: 0.0118 - val_accuracy: 0.9929 - val_loss: 0.0267
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 58s 123ms/step - accuracy: 0.9979 - loss: 0.0069 - val_accuracy: 0.9923 - val_loss: 0.0294
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 62s 132ms/step - accuracy: 0.9976 - loss: 0.0078 - val_accuracy: 0.9941 - val_loss: 0.0233
# 313/313 - 0s - 1ms/step - accuracy: 0.9873 - loss: 0.0403
# 313/313 - 4s - 12ms/step - accuracy: 0.9941 - loss: 0.0233
#
# LeNet Model Test accuracy: 0.9873
# VGG Model Test accuracy: 0.9941
